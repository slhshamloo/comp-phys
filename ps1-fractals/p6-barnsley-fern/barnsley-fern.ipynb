# %% [markdown]
# # Barnsley Fern
# ## Imports and config

# %%
from barnsley_fern import *
from matplotlib import rcParams, pyplot as plt

rcParams['text.usetex'] = True
directory = "../fig/"

# %% [markdown]
# ## Plot

# %%
fig, ax = plt.subplots(figsize=(4.7, 10))

x, y = barnsley_fern((0, 1), (0, 1), 25, 200000)
ax.plot(x, y, 'g,')

ax.set_axis_off()
ax.set_aspect('equal')
ax.autoscale_view(tight=True)
# plt.savefig(directory + "barnsley-fern.png", bbox_inches="tight", dpi=103)
